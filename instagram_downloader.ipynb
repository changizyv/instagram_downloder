# %% [markdown]
# ## **دانلود از اینستاگرام**

# %%
# !pip install instaloader

import instaloader

# ایجاد شیء Instaloader
L = instaloader.Instaloader()

# وارد کردن لینک اینستاگرام از کاربر
instagram_url = input("insert link of instagram post: ")

# دانلود محتوا
L.download_profile(instagram_url, profile_pic_only=False)
